# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.uniform(low=0,high=1,size=(100,100,3))
plt.imshow(x)

# %%
from skimage import io
image=io.imread("D:\\Codes\\GUI codes\\test.png")

# %%
io.imshow(image)

# %%
plt.imshow(image)

# %% [markdown]
# This is the markdown cell
# $\alpha^23$

# %%
x=np.arange(0,100)
y=x**2

# %%
plt.plot(x,y)
plt.title(r"y=x$^2$",fontname="Times New Roman")
plt.show()

# %%
pass

# %%
print("Hello World !!!")
# Out:
# Hello World !!!
